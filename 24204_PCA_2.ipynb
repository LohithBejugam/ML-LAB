# %%
import pandas as pd

data = {
    'Variable': [
        'Climate', 'Housing', 'Health', 'Crime',
        'Transportation', 'Education', 'Arts',
        'Recreation', 'Economy'
    ],
    '1': [0.190, 0.544, 0.782, 0.365, 0.585, 0.394, 0.985, 0.520, 0.142],
    '2': [0.017, 0.020, -0.605, 0.294, 0.085, -0.273, 0.126, 0.402, 0.150],
    '3': [0.207, 0.204, 0.144, 0.585, 0.234, 0.027, -0.111, 0.519, 0.239]
}

df = pd.DataFrame(data)

print(df)
# Out:
#          Variable      1      2      3
# 0         Climate  0.190  0.017  0.207
# 1         Housing  0.544  0.020  0.204
# 2          Health  0.782 -0.605  0.144
# 3           Crime  0.365  0.294  0.585
# 4  Transportation  0.585  0.085  0.234
# 5       Education  0.394 -0.273  0.027
# 6            Arts  0.985  0.126 -0.111
# 7      Recreation  0.520  0.402  0.519
# 8         Economy  0.142  0.150  0.239

# %%
for column in ['1', '2', '3']:
    index = df[column].abs().idxmax()
    print("Principal variable in Component", column, ":", df.loc[index, 'Variable'])
    print("Loading:", df.loc[index, column])
# Out:
# Principal variable in Component 1 : Arts
# Loading: 0.985
# Principal variable in Component 2 : Health
# Loading: -0.605
# Principal variable in Component 3 : Crime
# Loading: 0.585
